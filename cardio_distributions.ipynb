# %%
import pandas as pd

# %%
# Read in the CSV file
file = "cardio_training_clean.csv"
#file = "cardio_training.csv"
#df = pd.read_csv(file, skiprows=[0])
df_clean = pd.read_csv(file)
#df_1 = df_1.set_index('id')
#(bins =12, alpha=0.5
df_clean
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2   66.14   136.7    110     80            1     1
# 1          1   55       1   61.42   187.4    140     90            3     1
# 2          2   52       1   64.96   141.1    130     70            3     1
# 3          3   48       2   66.54   180.8    150    100            1     1
# 4          4   48       1   61.42   123.5    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 67477  99993   53       2   66.14   167.6    120     80            1     1
# 67478  99995   62       1   62.20   277.8    140     90            2     2
# 67479  99996   52       2   72.05   231.5    180     90            3     1
# 67480  99998   61       1   64.17   158.7    135     80            1     2
# 67481  99999   56       1   66.93   158.7    120     80            2     1
#
#        smoke  alco  active  cardio   BMI
# ...

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
#df_sns = sns.load_dataset(df_clean)

fig, axs = plt.subplots(4, 4, figsize=(18, 18))

#add margins to remove overlap of words in charts

sns.histplot(data=df_clean, x="age", kde=True, color="skyblue", ax=axs[0, 0])
sns.histplot(data=df_clean, x="gender", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df_clean, x="height", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df_clean, x="weight", kde=True, color="teal", ax=axs[1, 1])

sns.histplot(data=df_clean, x="ap_hi", kde=True, color="darkred", ax=axs[0, 2])
sns.histplot(data=df_clean, x="ap_lo", kde=True, color="palegreen", ax=axs[0, 3])
sns.histplot(data=df_clean, x="cholesterol", kde=True, color="darkmagenta", ax=axs[1, 2])
sns.histplot(data=df_clean, x="gluc", kde=True, color="royalblue", ax=axs[1, 3])

sns.histplot(data=df_clean, x="smoke", kde=True, color="darkgreen", ax=axs[2, 0])
sns.histplot(data=df_clean, x="alco", kde=True, color="slategray", ax=axs[2, 1])
sns.histplot(data=df_clean, x="active", kde=True, color="crimson", ax=axs[3, 0])
sns.histplot(data=df_clean, x="cardio", kde=True, color="goldenrod", ax=axs[3, 1])

sns.histplot(data=df_clean, x="BMI", kde=True, color="cyan", ax=axs[2, 2])
plt.show()
